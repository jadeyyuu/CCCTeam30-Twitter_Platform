# %%
import tweepy
import pandas as pd
auth = tweepy.OAuthHandler("mHwDkHtAr0YsmrJhuVpA9MQhH", "8OXET1pwHp70H1R5Ed0w9NEeBXrZVJOqa9JLbgEtO6xjLq8OlV")
auth.set_access_token("1384514435385937926-ufOKI9oTRQrM0ibYTpRBDIuR7klIYC", "0NNpZ0zPHWylv7p6MLPwjoZPuCZsqHXsbBNS00GElwfTX")
api = tweepy.API(auth)

# %%
me = api.me()
me.screen_name
# Out:
# 'Chelsea49123764'

# %%
def extract_timeline_as_df(timeline_list):
    columns = set() # set items have to be unique, rather than a list
    allowed_types = [str,int]
    tweet_data = []
    for status in timeline_list:
    #     print(status.text)
    #     print(vars(status)) # print out a dictionary
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
        for k in keys:
            v_type = type(status_dict[k])
            if v_type in allowed_types:
                single_tweet_data[k] = status_dict[k]
                columns.add(k)

        tweet_data.append(single_tweet_data)

    header_cols = list(columns)
    header_cols.append("user")
    header_cols.append("author")
    df = pd.DataFrame(tweet_data, columns=header_cols)
    return df

# %%
my_timeline = api.home_timeline()

# %%
df2 = extract_timeline_as_df(my_timeline)
df2
# Out:
#   lang      text  retweet_count           source               id_str  \
# 0   en  Hi there              0  Twitter Web App  1384828390864084993
# 1   en   testing              0  Twitter Web App  1384828363307511814
#
#    favorite_count                  source_url                   id  \
# 0               0  https://mobile.twitter.com  1384828390864084993
# 1               0  https://mobile.twitter.com  1384828363307511814
#
#               user           author
# 0  Chelsea49123764  Chelsea49123764
# 1  Chelsea49123764  Chelsea49123764

# %%
# extract other user timeline
user = api.get_user("code")
user_timeline = user.timeline()
df3 = extract_timeline_as_df(user_timeline)
df3.head()
# Out:
#   lang                                               text  \
# 0   en  RT @msdevCA: Microsoft Senior Software Enginee...
# 1   en  To all C++ devs 💻 CMakePresets.json support is...
# 2   en  RT @davorabbit: This is super cool! The widget...
# 3   en  RT @dzhavatushev: I'm humbled to see my "CSS F...
# 4   en  RT @_tanhakabir: REST Book is published on the...
#
#    in_reply_to_user_id  in_reply_to_status_id  retweet_count  \
# 0                  NaN                    NaN             13
# 1                  NaN                    NaN             15
# 2                  NaN                    NaN              9
# 3                  NaN                    NaN             49
# 4                  NaN                    NaN             33
#
#   in_reply_to_status_id_str  quoted_status_id           source  \
# 0                       NaN               NaN  Twitter Web App
# 1                       NaN      1.384546e+18           Buffer
# 2                       NaN      1.383334e+18           Buffer
# 3                       NaN               NaN           Buffer
# 4                       NaN               NaN           Buffer
#
#                 id_str  favorite_count in_reply_to_screen_name  \
# 0  1384597048310177797               0                     NaN
# 1  1384572074941878273              92                     NaN
# 2  1384533824017678339               0                     NaN
# 3  1384265807786512390               0                     NaN
# 4  1384210207639621642               0                     NaN
#
#                    source_url quoted_status_id_str                   id  \
# 0  https://mobile.twitter.com                  NaN  1384597048310177797
# 1          https://buffer.com  1384546094391037962  1384572074941878273
# 2          https://buffer.com  1383333912470974470  1384533824017678339
# 3          https://buffer.com                  NaN  1384265807786512390
# 4          https://buffer.com                  NaN  1384210207639621642
#
#   in_reply_to_user_id_str  user author
# 0                     NaN  code   code
# 1                     NaN  code   code
# 2                     NaN  code   code
# 3                     NaN  code   code
# 4                     NaN  code   code
