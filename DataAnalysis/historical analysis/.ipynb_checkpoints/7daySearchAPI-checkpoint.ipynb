# %%
import tweepy
import json
import ijson
import twitter
import pandas as pd
from TwitterAPI import TwitterAPI
from TwitterAPI import TwitterPager

consumer_key = "gsyrYWXRhPY67MeQueFo6sytq"
consumer_secret = "fUMk8GJEjlHFSmmoEI4asD3dT3KQcD422gRWsueWScDpJS5oqU"
access_token_key = "1384514435385937926-s8PAapPbfZNIVroChcNbrPhUIQezGW"
access_token_secret = "KiT8i61dN5uQgEjwQ7TliR3OjK8jDhUXSsyMWyS2oB2ST"
api = TwitterAPI(consumer_key=consumer_key,
                     consumer_secret=consumer_secret,
                     access_token_key=access_token_key,
                     access_token_secret=access_token_secret)

# %%
# center pt of Victoria: http://www.ga.gov.au/scientific-topics/national-location-information/dimensions/centre-of-australia-states-territories#heading-14
# Location: 36° 51' 15" South, 144° 16' 52" East
# Position on SJ55-01 Bendigo 1:250 000 and 7724 Bendigo 1:100 000 scale maps.
# melb - 37.8136° S, 144.9631° E

# %%
with open('7daytweet_id.json') as f:
    tweet_id = json.load(f)['id']
len(tweet_id)
# Out:
# 5323

# %%
count=0
results=[]
r = TwitterPager(api, 'search/tweets', {'q': ['covid','covid-19','coronavirus','vaccine','vaccination','vaccinate', 'injection', 'inject'],'lang': 'en','count': 1000,'geocode':'-37.840935,144.946457,10km'})
for item in r.get_iterator():
    if 'text' in item:
        if item['text'].startswith("RT")==False and item['id'] not in tweet_id:
            results.append(item)
            tweet_id.append(item['id'])
            count+=1
            print(len(tweet_id))
    elif 'message' in item and item['code'] == 88:
        print ('SUSPEND, RATE LIMIT EXCEEDED: %s\n' % item['message'])
        break
# Out:
# 5253
# 5254
# 5255
# 5256
# 5257
# 5258
# 5259
# 5260
# 5261
# 5262
# 5263
# 5264
# 5265
# 5266
# 5267
# 5268
# 5269
# 5270
# 5271
# 5272
# 5273
# 5274
# 5275
# 5276
# 5277
# 5278
# 5279
# 5280
# 5281
# 5282
# 5283
# 5284
# 5285
# 5286
# 5287
# 5288
# 5289
# 5290
# 5291
# 5292
# 5293
# 5294
# 5295
# 5296
# 5297
# 5298
# 5299
# 5300
# 5301
# 5302
# 5303
# 5304
# 5305
# 5306
# 5307
# 5308
# 5309
# 5310
# 5311
# 5312
# 5313
# 5314
# 5315
# 5316
# 5317
# 5318
# 5319
# 5320
# 5321
# 5322
# 5323
# 5324
# 5325
# 5326
# 5327
# 5328
# 5329
# 5330
# 5331
# 5332
# 5333
# 5334
# 5335
# 5336
# 5337
# 5338
# 5339
# 5340
# 5341
# 5342
# 5343
# 5344
# 5345
# 5346
# 5347
# 5348
# 5349
# 5350
# 5351
# 5352
# 5353
# 5354
# 5355
# 5356
# 5357
# 5358
# 5359
# 5360
# 5361
# 5362
# 5363
# 5364
# 5365
# 5366
# 5367
# 5368
# 5369
# 5370
# 5371
# 5372
# 5373
# 5374
# 5375
# 5376
# 5377
# 5378
# 5379
# 5380
# 5381
# 5382
# 5383
# 5384
# 5385
# 5386
# 5387
# 5388
# 5389
# 5390
# 5391
# 5392
# 5393
# 5394
# ...

# %%
len(tweet_id['id'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-94f44529222b> in <module>
# ----> 1 len(tweet_id['id'])
#
# TypeError: list indices must be integers or slices, not str

# %%
data = {'results':results}
import os
with open('7day_unformatted/7dayTweetData2.json', 'w') as outfile:
    json.dump(data, outfile)
os.system("jq . 7day_unformatted/7dayTweetData2.json>7day/7dayTweetData_formatted2.json")
tweet_id = {'id':tweet_id}
with open('7daytweet_id.json', 'w') as outfile:
    json.dump(tweet_id, outfile)

# %%
import glob
tweet_id=[]
time = []
text = []
location =[]
read_files = glob.glob("7day/7dayTweetData_formatted*.json")
for file in read_files:
    with open(str(file), 'r') as f:
        objects = ijson.items(f, 'results.item')
        for row in objects:  
            if row['text'].startswith("RT") == False and row['id'] not in tweet_id:
                location.append(row['user']['location'])
                time.append(row['created_at'])
                text.append(row['text'])
                tweet_id.append(row['id'])
data = pd.DataFrame({"text":text,"time":time,"location":location},columns=["text","time","location"])
data['time'] = pd.to_datetime(data['time']).dt.date
tweet_id = {'id':tweet_id}

# %%
with open('7daytweet_id.json', 'w') as outfile:
    json.dump(tweet_id, outfile)

# %%
data
# Out:
#                                                    text        time  \
# 0     Demanding ASIC help businesses to survive in t...  2021-04-29
# 1     Oxygen is the new currency on India’s morbid n...  2021-04-29
# 2     Victoria's proposed COVID-19 quarantine facili...  2021-04-29
# 3     After 16 Covid leaks in six months, it’s time ...  2021-04-29
# 4     @L_Glanville urging targeted mental health sup...  2021-04-29
# ...                                                 ...         ...
# 5318  @marcbernardin How the hell did they film this...  2021-04-20
# 5319  @GoGrandesflower @POTUS Yeah you can. Vaccine ...  2021-04-20
# 5320  @Allie8170 @POTUS Nah people are dead from the...  2021-04-20
# 5321  @DrEricDing @PaulSorrentino3 @WicMar Transferr...  2021-04-20
# 5322  Just a joke on RCB, by no means making fun of ...  2021-04-20
#
#                    location
# 0      Melbourne, Australia
# 1     Melbourne, Australia
# 2                 Melbourne
# 3                 Melbourne
# ...
