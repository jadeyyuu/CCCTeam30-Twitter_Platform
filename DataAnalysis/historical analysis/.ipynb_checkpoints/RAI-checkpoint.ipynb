# %%
import pandas as pd
RAI = pd.read_json("RAI_18-20.json")
# RAI_vic = RAI_vic[RAI_vic['state']=="VIC"].dropna().mean().reset_index().sort_values(by=['index'])
# # RAI_vic = RAI_vic.replace({"rai_national_total_":""})
RAI
# Out:
#      unique_id  rai_national_total_2019_q1  rai_national_total_2019_q2  \
# 0          293                  134.351949                  113.383726
# 1          328                  163.461538                  148.601399
# 2          330                         NaN                         NaN
# 3          333                         NaN                         NaN
# 4          334                         NaN                         NaN
# ..         ...                         ...                         ...
# 750       2331                  102.163461                   98.076923
# 751       2332                  107.776838                  111.451049
# 752       2333                  102.163461                  104.337152
# 753       2334                   92.525399                   96.153846
# 754       2335                         NaN                         NaN
#
#      rai_national_total_2018_q4  rai_national_total_2018_q3  \
# ...

# %%
import geopandas as gpd
data = gpd.read_file('shp/3de7fa5b-c3c3-4880-b95f-91e26fd8487d.shp')

# %%
data
# Out:
#      unique_id  rai_natio0  rai_natio1  rai_natio2  rai_natio3  rai_natio4  \
# 0         1051         NaN         NaN         NaN         NaN         NaN
# 1         1052         NaN         NaN         NaN         NaN         NaN
# 2         1056  272.435897         NaN  306.490385  265.072765         NaN
# 3         1057  222.902098  204.326923  222.902098  204.326923  204.326923
# 4         1058         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 750        426         NaN         NaN         NaN         NaN         NaN
# 751        428         NaN         NaN         NaN         NaN         NaN
# 752        429         NaN         NaN         NaN         NaN         NaN
# 753        430         NaN         NaN         NaN         NaN         NaN
# 754        431         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
import numpy as np
# data.loc[np.random.choice(data.index, 40), 'rai_natio9'] = np.nan
data[data['state']=='VIC'].plot(column='rai_natio9', missing_kwds={'color': 'lightgrey'},cmap='OrRd',)
# Out:
# <AxesSubplot:>

# %%
VIC = gpd.read_file('australia_administrative_victoria_boundary/australia_administrative_victoria_boundary.shp')

# %%
VIC
# Out:
#    gid       id country               name    enname            locname  \
# 0    1  2316741     AUS           Victoria  Victoria           Victoria
# 1    2  4246123     AUS  Barwon South West      None  Barwon South West
# 2    3  4246268     AUS          Gippsland      None          Gippsland
# 3    4  4246144     AUS          Grampians      None          Grampians
# 4    5  4246124     AUS  Greater Melbourne      None  Greater Melbourne
# 5    6  4246208     AUS               Hume      None               Hume
# 6    7  4246154     AUS      Loddon Mallee      None      Loddon Mallee
#
#   offname        boundary  adminlevel   wikidata  \
# 0    None  administrative           4     Q36687
# 1    None  administrative           5  Q17984901
# 2    None  administrative           5   Q1526531
# 3    None  administrative           5  Q17984902
# 4    None  administrative           5       None
# 5    None  administrative           5  Q17007284
# ...

# %%
VIC.plot(edgecolor='white')
# Out:
# <AxesSubplot:>

# %%
pd.read_json("2020Mean_cityGeo.json")
# Out:
#                  city  count  \
# 0               Lorne      9
# 1        Neerim South      4
# 2          Port Fairy      6
# 3          Wangaratta     10
# 4            Langkoop      1
# ..                ...    ...
# 261  Moe - Newborough      6
# 262          Merrigum      1
# 263          Colignan      1
# 264       Warrnambool     10
# 265         Inverloch      4
#
#                                               geometry
# 0    [{'address_components': [{'long_name': 'Lorne'...
# 1    [{'address_components': [{'long_name': 'Neerim...
# 2    [{'address_components': [{'long_name': 'Port F...
# 3    [{'address_components': [{'long_name': 'Wangar...
# 4    [{'address_components': [{'long_name': 'Langko...
# ..                                                 ...
# 261  [{'address_components': [{'long_name': 'Moe - ...
# 262  [{'address_components': [{'long_name': 'Merrig...
# 263  [{'address_components': [{'long_name': 'Colign...
# ...
